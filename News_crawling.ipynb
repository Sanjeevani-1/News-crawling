# %%
from datetime import date
today=date.today()

# %%
d=today.strftime("%m-%d-%y")
print('Date= ',d)
# Out:
# Date=  04-28-20

# %%
cnn_url='https://edition.cnn.com/world/live-news/coronavirus-pandemic-{}-intl/index.html'.format(d)

# %%
print(cnn_url)
# Out:
# https://edition.cnn.com/world/live-news/coronavirus-pandemic-04-28-20-intl/index.html

# %%
from bs4 import BeautifulSoup
import requests

# %%
html=requests.get(cnn_url).text

# %%
soup=BeautifulSoup(html)
print(soup.title)
# Out:
# <title data-rh="true">Coronavirus pandemic: Updates from around the world - CNN</title>

# %%
import spacy
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
for link in soup.find_all("h2"):
    
    print("Headline : {}".format(link.text))
    for ent in nlp(link.text).ents: 
      print("\tText : {}, Entity : {}".format(ent.text, ent.label_))
# Out:
# Headline : What you need to know
# Headline : "Unfair and irresponsible" to label Chinese products "faulty," says China after India cancels testing kit order
# 	Text : Chinese, Entity : NORP
# 	Text : China, Entity : GPE
# 	Text : India, Entity : GPE
# Headline : Lewis Hamilton says he misses Formula 1 racing "every day"
# 	Text : Lewis Hamilton, Entity : PERSON
# 	Text : Formula 1, Entity : PRODUCT
# Headline : Former New Zealand PM says early ban on Chinese travellers helped curb spread of outbreak
# 	Text : New Zealand, Entity : GPE
# 	Text : Chinese, Entity : NORP
# Headline : New figures reveal scale of job losses in Spain due to outbreak
# 	Text : Spain, Entity : GPE
# Headline : Black barbershop owners are divided over coronavirus social distancing
# Headline : HSBC hits pause on mass layoffs after profits plunge by nearly 50%
# 	Text : HSBC, Entity : ORG
# 	Text : nearly 50%, Entity : PERCENT
# Headline : Coronavirus vaccine won't be ready until end of 2021 under "most optimistic" scenario - European expert
# 	Text : 2021, Entity : DATE
# Headline : Survey gives insight into UK public's view of coronavirus response by media
# 	Text : UK, Entity : GPE
# Headline : One billion coronavirus infections possible in crisis-affected countries, warns IRC
# 	Text : One billion, Entity : CARDINAL

# %%
nbc_url='https://www.nbcnews.com/health/coronavirus'
cnbc_rss_url='https://www.cnbc.com/id/10000108/device/rss/rss.html'

# %%
urls=[cnn_url, nbc_url,cnbc_rss_url]
formats=['html.parser','html.parser','xml']
tags=['h2','h2','description']
website=['CNN', 'NBC','CNBC']

# %%
crawl_len=0
for url in urls:
    print("Crawling web page ..........{}".format(url))
    response = requests.get(url)
    soup = BeautifulSoup(response.content,formats[crawl_len])

    for link in soup.find_all(tags[crawl_len]):

      if(len(link.text.split(" ")) > 4):
        print("Headline : {}".format(link.text))

        entities=[]
        for ent in nlp(link.text).ents: 
          print("\tText : {}, Entity : {}".format(ent.text, ent.label_)) 

    crawl_len=crawl_len+1
# Out:
# Crawling web page ..........https://edition.cnn.com/world/live-news/coronavirus-pandemic-04-28-20-intl/index.html
# Headline : What you need to know
# Headline : Portugal will end state of emergency this week
# 	Text : Portugal, Entity : GPE
# 	Text : this week, Entity : DATE
# Headline : Scottish government recommends wearing face coverings in public places
# 	Text : Scottish, Entity : NORP
# Headline : 125,000 birthday cards sent to war veteran who raised millions for UK's health service
# 	Text : 125,000, Entity : CARDINAL
# 	Text : millions, Entity : CARDINAL
# 	Text : UK, Entity : GPE
# Headline : Just joining us? Here are the key updates you've missed
# Headline : "Unfair and irresponsible" to label Chinese products "faulty," says China after India cancels testing kit order
# 	Text : Chinese, Entity : NORP
# 	Text : China, Entity : GPE
# 	Text : India, Entity : GPE
# Headline : Lewis Hamilton says he misses Formula 1 racing "every day"
# 	Text : Lewis Hamilton, Entity : PERSON
# 	Text : Formula 1, Entity : PRODUCT
# Headline : Former New Zealand PM says early ban on Chinese travellers helped curb spread of outbreak
# 	Text : New Zealand, Entity : GPE
# 	Text : Chinese, Entity : NORP
# Headline : New figures reveal scale of job losses in Spain due to outbreak
# 	Text : Spain, Entity : GPE
# Headline : Black barbershop owners are divided over coronavirus social distancing
# Crawling web page ..........https://www.nbcnews.com/health/coronavirus
# Headline : Trump lays out new testing 'blueprint' as states weigh reopening
# Headline : Live Blog / Latest news on the global pandemic
# Headline : America's best Instagram quarantine celebrity is a 64-year-old Southern gay man
# 	Text : America, Entity : GPE
# 	Text : Instagram, Entity : ORG
# 	Text : Southern, Entity : NORP
# Headline : America's obsession with Trump lets health officials like Dr. Fauci off the hook
# 	Text : America, Entity : GPE
# 	Text : Trump, Entity : GPE
# 	Text : Fauci, Entity : PERSON
# Headline : Those 'COVID-19' weight gain jokes reveal the toxic power of diet culture
# Headline : In a plagued stretch of Louisiana known as Cancer Alley, coronavirus compounds deaths
# 	Text : Louisiana, Entity : GPE
# 	Text : Cancer Alley, Entity : PERSON
# Headline : Coronavirus forces America's musicians down a new and delightful path
# 	Text : America, Entity : GPE
# Headline : Prisons overwhelmed, inmates terrified and social dynamics changing behind bars
# Headline : Blue Angels and Thunderbirds to honor coronavirus responders with flyovers
# 	Text : Blue Angels, Entity : ORG
# 	Text : Thunderbirds, Entity : ORG
# Headline : Face masks for passengers now required on all JetBlue flights
# 	Text : JetBlue, Entity : ORG
# Headline : 'Naked concerns': Doctors strip down to protest lack of protective equipment
# Headline : Pug tests positive for coronavirus, may be first for dog in U.S.
# 	Text : first, Entity : ORDINAL
# 	Text : U.S., Entity : GPE
# Headline : Coronavirus reshapes special election for Cummings' Maryland House seat
# 	Text : Cummings, Entity : ORG
# 	Text : Maryland House, Entity : ORG
# Headline : Troy Sneed, Grammy-nominated gospel singer, dies at 52 from coronavirus complications
# 	Text : Troy Sneed, Entity : PERSON
# 	Text : 52, Entity : CARDINAL
# Headline : Over 30 percent of Americans have witnessed COVID-19 bias against Asians, poll says
# 	Text : Over 30 percent, Entity : PERCENT
# 	Text : Americans, Entity : NORP
# 	Text : Asians, Entity : NORP
# Headline : Detroit health care worker dies after being denied coronavirus test 4 times, daughter says
# 	Text : Detroit, Entity : GPE
# 	Text : 4, Entity : CARDINAL
# Headline : California men accused of peddling millions of nonexistent masks in alleged coronavirus scam
# 	Text : California, Entity : GPE
# 	Text : millions, Entity : CARDINAL
# Headline : Trump lays out new coronavirus testing 'blueprint' as states weigh reopening
# Headline : Chicago mayor blasts video of 'reckless and utterly unacceptable' house party
# 	Text : Chicago, Entity : GPE
# Headline : L.A. Lakers qualified for an emergency PPP loan — why didn't nonprofits?
# 	Text : L.A. Lakers, Entity : ORG
# 	Text : PPP, Entity : ORG
# Headline : Julián Castro: Latinos grapple with 'the worst of all worlds' amid coronavirus pandemic
# 	Text : Julián Castro, Entity : PERSON
# Headline : 'Extremely disappointing' and 'entirely predictable' — slowdowns and lockouts plague second round of PPP
# 	Text : second, Entity : ORDINAL
# 	Text : PPP, Entity : ORG
# Headline : Have you been mistakenly accused of not social distancing because of apparent stereotyping? Share your experience
# Headline : Inside an 'army' of COVID-19 contact tracers in Massachusetts
# 	Text : Massachusetts, Entity : GPE
# Headline : Pushback on Trump state 'bailout' swipe: Who's really getting rescued?
# Headline : S. Korea is leading the pack in its coronavirus response. The price? A new way of life.
# 	Text : S. Korea, Entity : GPE
# Headline : Instagram's cofounders left Facebook. Now, they're working on a coronavirus website.
# 	Text : Instagram, Entity : ORG
# 	Text : Facebook, Entity : ORG
# Headline : Magic Johnson: Sports will first return without fans in the stands
# 	Text : Magic Johnson, Entity : PERSON
# 	Text : first, Entity : ORDINAL
# Headline : L.A. Lakers return $4.6M in federal relief aid
# 	Text : L.A. Lakers, Entity : ORG
# 	Text : $4.6M, Entity : MONEY
# Headline : Trump: Federal govt. shouldn't rescue states and cities struggling under pandemic
# Headline : As most remain home, some states begin to slowly reopen
# Headline : In Detroit, grief runs deep as city grapples with COVID-19
# 	Text : Detroit, Entity : GPE
# Headline : Pelosi says Democrats will push for mail-in voting in next relief package
# 	Text : Pelosi, Entity : ORG
# 	Text : Democrats, Entity : NORP
# Headline : 'Another pandemic': Domestic abuse calls spike in Latin America
# 	Text : Latin America, Entity : LOC
# Headline : Nursing home industry pushes for legal immunity during COVID-19 emergency
# Headline : Tyson Foods chairman warns: 'The food supply chain is breaking'
# 	Text : Tyson Foods, Entity : ORG
# Headline : Doctor prevented from seeing kids after husband said she posed coronavirus threat
# Headline : As 'quarantine fatigue' sets in, more people venturing out, study finds
# Headline : Automakers adjust to 'new normal' as they prepare to reopen plants
# Headline : His fight with virus is over, but British PM warns country now is time of 'maximum risk'
# 	Text : British, Entity : NORP
# Headline : Grieving is hard, but new text service means you don't have to do it alone
# Headline : Coronavirus may be strike three for the Burlington Bees
# 	Text : three, Entity : CARDINAL
# 	Text : the Burlington Bees, Entity : PRODUCT
# Headline : Ballot initiatives struggle to qualify for 2020 election
# 	Text : 2020, Entity : DATE
# Headline : Louisiana pastor, while on house arrest, again defies coronavirus order with church service
# 	Text : Louisiana, Entity : GPE
# Headline : Governors urge Trump to keep briefings 'fact-based' after disinfectant comments
# 	Text : Trump, Entity : ORG
# Headline : Spanish flu-era diaries give Ohio family hope
# 	Text : Spanish, Entity : NORP
# 	Text : Ohio, Entity : GPE
# Headline : Small businesses say they need more than 2 months of help to survive coronavirus crisis
# 	Text : more than 2 months, Entity : DATE
# Headline : Rolling Stones coronavirus lockdown single 'Living in a Ghost Town' hits No. 1 on iTunes
# 	Text : 1, Entity : CARDINAL
# 	Text : iTunes, Entity : ORG
# Headline : As Dr. Fauci, Brad Pitt diagnoses Trump on 'SNL'
# 	Text : Fauci, Entity : PERSON
# 	Text : Brad Pitt, Entity : PERSON
# 	Text : Trump, Entity : PERSON
# 	Text : SNL, Entity : ORG
# Headline : 'Outrageous,' 'irresponsible': Governors slam McConnell over bankruptcy comments
# 	Text : slam McConnell, Entity : PERSON
# Headline : Birx: U.S. needs a 'breakthrough' on antigen testing to aid in reopening
# 	Text : Birx, Entity : GPE
# 	Text : U.S., Entity : GPE
# Headline : Critics say police target minorities more than white protesters over social distancing
# Headline : Kids miss more than just class with schools closed. How can you help them adjust?
# Headline : VA has provided few answers around agency's virus study, veteran advocates say
# 	Text : VA, Entity : GPE
# Headline : The Zoom shiva: Jewish funerals and mourning in the age of COVID
# 	Text : Zoom, Entity : PERSON
# 	Text : Jewish, Entity : NORP
# Headline : For students in rural Puerto Rico, remote learning amid coronavirus is a tough challenge
# 	Text : Puerto Rico, Entity : GPE
# Headline : As restaurants stay closed, chefs still cooking — for health care workers
# Headline : WHO warns there's no evidence of coronavirus immunity as global death toll reaches 200,000
# 	Text : 200,000, Entity : CARDINAL
# Headline : MSNBC Special Report: Testing and the Road to Reopening
# Headline : Want a mask contract? A White House connection helps
# 	Text : White House, Entity : ORG
# Headline : At a NY nursing home forced to take COVID-19 patients, 24 residents have died
# 	Text : NY, Entity : GPE
# 	Text : 24, Entity : CARDINAL
# Headline : Affairs, hoarders and hope: Read anonymous confessions in the time of the coronavirus
# Headline : NBC News special report: 'Coronavirus Pandemic'
# 	Text : NBC News, Entity : ORG
# Headline : Coronavirus: What you need to know
# Headline : 'Into The Red Zone': An NBC News NOW documentary
# 	Text : NBC News, Entity : ORG
# Headline : Portrait of a neighborhood under lockdown
# 	Text : Portrait, Entity : PERSON
# Headline : Photos capture empty cities across the globe
# Headline : New Yorkers are giving nightly ovations to health workers. These are their portraits
# 	Text : New Yorkers, Entity : NORP
# Headline : Exonerated man freed from prison, now in hotel quarantine: 'I could watch Netflix!'
# 	Text : Netflix, Entity : PERSON
# Headline : America needs universal testing. Here's how we'll get there.
# 	Text : America, Entity : GPE
# Headline : Drinking bleach will not cure coronavirus. Here's what it could do instead.
# Headline : Touch a shadow, 'You're it!': New routines as Denmark returns to school
# 	Text : Denmark, Entity : GPE
# Headline : Trump's White House briefings may be scaled back
# 	Text : Trump, Entity : GPE
# 	Text : White House, Entity : ORG
# Headline : California heat wave draws large crowds to beaches despite stay-at-home order
# 	Text : California, Entity : GPE
# Headline : White House considering scaling back Trump's daily coronavirus briefings in coming weeks
# 	Text : White House, Entity : ORG
# 	Text : Trump's, Entity : ORG
# 	Text : daily, Entity : DATE
# 	Text : coming weeks, Entity : DATE
# Headline : White House considers scaling back daily briefings
# 	Text : White House, Entity : ORG
# 	Text : daily, Entity : DATE
# Headline : Dad, 32, writes heart-wrenching note to wife, kids before dying of coronavirus
# 	Text : 32, Entity : DATE
# Headline : Fauci's absence from recent coronavirus briefings draws notice
# 	Text : Fauci, Entity : ORG
# Headline : Global coronavirus death toll surpasses 200,000, as world leaders commit to finding vaccine
# 	Text : 200,000, Entity : CARDINAL
# Crawling web page ..........https://www.cnbc.com/id/10000108/device/rss/rss.html
# Headline : Latest news for health care.
# Headline : On Tuesday, de Blasio announced plans to hire 1,000 health workers to track coronavirus cases as well as anyone who has come into contact with someone who's tested positive for Covid-19.
# 	Text : Tuesday, Entity : DATE
# 	Text : de Blasio, Entity : ORG
# 	Text : 1,000, Entity : CARDINAL
# Headline : Health officials in the UK have warned that Covid-19 could be causing a new and rare inflammatory condition in children.
# 	Text : UK, Entity : GPE
# Headline : Quest screens patients online to determine whether or not an antibody test is appropriate and then sends them to have their blood drawn at one of Quest's 2,200 laboratories, Quest said.
# 	Text : one, Entity : CARDINAL
# 	Text : Quest, Entity : ORG
# 	Text : 2,200, Entity : CARDINAL
# 	Text : Quest, Entity : ORG
# Headline : Covid-19 has infected more than 3 million people around the world, killing at least 211,522 people.
# 	Text : Covid-19, Entity : ORG
# 	Text : more than 3 million, Entity : CARDINAL
# 	Text : at least 211,522, Entity : CARDINAL
# Headline : Stocks are set to advance as Dow stocks 3M, Caterpillar and Pfizer rise on earnings and U.S. oil prices come off their lows.
# 	Text : Dow, Entity : ORG
# 	Text : 3, Entity : CARDINAL
# 	Text : Caterpillar, Entity : ORG
# 	Text : Pfizer, Entity : PERSON
# 	Text : U.S., Entity : GPE
# Headline : As the coronavirus pandemic continues to escalate, doctors around the U.S. are joining lawyers and financial advisors in urging Americans to create the essential documents necessary to help medical providers better coordinate care.
# 	Text : U.S., Entity : GPE
# 	Text : Americans, Entity : NORP
# Headline : It estimates it can potentially produce "millions" of coronavirus vaccine doses by the end of this year and "hundreds of millions of doses" in 2021 if the vaccine is successful.
# 	Text : millions, Entity : CARDINAL
# 	Text : the end of this year, Entity : DATE
# 	Text : hundreds of millions, Entity : CARDINAL
# 	Text : 2021, Entity : DATE
# Headline : Germany's coronavirus infection rate has edged up, prompting the head of the country's infectious diseases institute to urge people to stay at home as much as possible.
# 	Text : Germany, Entity : GPE
# Headline : The U.S. is not even "remotely prepared" to re-open, an expert said on Tuesday as some states are set to lift lockdowns that had been imposed to contain the coronavirus outbreak.
# 	Text : U.S., Entity : GPE
# 	Text : Tuesday, Entity : DATE
# Headline : European markets gained on Tuesday as investors monitor the potential easing of coronavirus lockdowns around the world, along with a host of corporate earnings.
# 	Text : European, Entity : NORP
# 	Text : Tuesday, Entity : DATE
# Headline : Germany's coronavirus infection rate has reportedly edged up while Spain's daily death rate has eased.
# 	Text : Germany, Entity : GPE
# 	Text : Spain, Entity : GPE
# 	Text : daily, Entity : DATE
# Headline : American Airlines will require flight attendants wear face masks and will provide passengers with them because of concerns about coronavirus.
# 	Text : American Airlines, Entity : ORG
# Headline : Boeing is planning to resume production of 787 Dreamliners at its South Carolina factory early next month after a nearly monthlong closure because of the coronavirus.
# 	Text : Boeing, Entity : ORG
# 	Text : 787, Entity : CARDINAL
# 	Text : South Carolina, Entity : GPE
# 	Text : early next month, Entity : DATE
# Headline : "All those things and many more, changes to our physical facilities, for instance, will be necessary for us to conclude that we are safe," Purdue University President Mitch Daniels told CNBC.
# 	Text : Purdue University, Entity : ORG
# 	Text : Mitch Daniels, Entity : PERSON
# 	Text : CNBC, Entity : ORG
# Headline : The news conference, to be held in the Rose Garden, appears to replace the daily coronavirus task force briefing, which had been scheduled for the same time Monday. Trump has been the subject of criticism for his dangerous speculation about whether injecting disinfectants can help to treat Covid-19.
# 	Text : the Rose Garden, Entity : FAC
# 	Text : daily, Entity : DATE
# 	Text : the same time Monday, Entity : DATE
# 	Text : Trump, Entity : PERSON
# Headline : More than 1.9 million unemployment claims have been filed in Texas since the outbreak began and the state has paid out more than $2 billion, Abbott said.
# 	Text : More than 1.9 million, Entity : CARDINAL
# 	Text : Texas, Entity : GPE
# 	Text : more than $2 billion, Entity : MONEY
# 	Text : Abbott, Entity : PERSON
# Headline : San Francisco Mayor London Breed announced Monday that health officials are extending the city's stay-at-home order through May.
# 	Text : San Francisco, Entity : GPE
# 	Text : London Breed, Entity : PERSON
# 	Text : Monday, Entity : DATE
# Headline : "Hospitals want to assure patients that if they have an issue, dial 911 and get to the hospital," Medtronic Executive Chairman Omar Ishrak told CNBC.
# 	Text : 911, Entity : CARDINAL
# 	Text : Medtronic Executive, Entity : ORG
# 	Text : Omar Ishrak, Entity : PERSON
# 	Text : CNBC, Entity : ORG
# Headline : Some countries are considering issuing so-called immunity passports to people who have antibodies against Covid-19, enabling them to travel or return to work.
# Headline : "We believe that the overarching federal plan seems to be very much based on science," Dr. Mike Ryan, executive director of WHO's emergencies program, said of the U.S.
# 	Text : Mike Ryan, Entity : PERSON
# 	Text : WHO, Entity : ORG
# 	Text : U.S., Entity : GPE
# Headline : Cuomo's remarks come as health experts and political leaders, including those at the White House, warn that the coronavirus is likely to persist through the fall and winter.
# 	Text : Cuomo, Entity : PERSON
# 	Text : the White House, Entity : ORG
# 	Text : winter, Entity : DATE
# Headline : A new CNBC index that tracks companies working on a Covid-19 cure shows how closely the stock market is following drug equities.
# 	Text : CNBC, Entity : ORG
# Headline : The World Health Organization warned Monday that children across the world will die as the coronavirus pandemic forces some countries to temporarily halt vaccinations for other deadly diseases such as polio.
# 	Text : The World Health Organization, Entity : ORG
# 	Text : Monday, Entity : DATE
# Headline : Say hello to the high-walled cubicles made famous in the 1999 film, "Office Space," because they're about to make a comeback.
# 	Text : 1999, Entity : DATE
# 	Text : Office Space, Entity : WORK_OF_ART
# Headline : "Now how long that immunity lasts, how strong it is, we don't know," the former FDA chief told CNBC on Monday.
# 	Text : FDA, Entity : ORG
# 	Text : CNBC, Entity : ORG
# 	Text : Monday, Entity : DATE
# Headline : Earlier last week, Cuomo released the preliminary results of a statewide coronavirus antibody testing study, which indicated that an estimated 13.9% of the New Yorkers have likely had Covid-19 already.
# 	Text : Earlier last week, Entity : DATE
# 	Text : Cuomo, Entity : ORG
# 	Text : an estimated 13.9%, Entity : PERCENT
# 	Text : New Yorkers, Entity : NORP
# Headline : Boeing is preparing for a yearslong slump in air travel, which will force the manufacturer to shrink to meet weak demand.
# 	Text : Boeing, Entity : ORG
# Headline : CVS and UPS will start using drones to deliver prescription medications to The Village residents, a Florida retirement community, in order to maintain social distancing measures.
# 	Text : CVS, Entity : ORG
# 	Text : UPS, Entity : ORG
# 	Text : Village, Entity : ORG
# 	Text : Florida, Entity : GPE
# Headline : WHO is holding a press briefing on the coronavirus pandemic.
# Headline : Capacity to test broadly throughout the population and to trace contacts with those who test positive for Covid-19 is a crucial element of the state's plans to lift restrictions, New York Gov. Andrew Cuomo have previously said.
# 	Text : New York, Entity : GPE
# 	Text : Andrew Cuomo, Entity : PERSON

# %%
crawl_len=0
news_dict=[]
for url in urls:
    response = requests.get(url)
    soup = BeautifulSoup(response.content,formats[crawl_len])

    for link in soup.find_all(tags[crawl_len]):

      if(len(link.text.split(" ")) > 4):

        entities=[]

        entities=[(ent.text, ent.label_) for ent in nlp(link.text).ents]

        news_dict.append({'website':website[crawl_len],'url': url,'headline':link.text,'entities':entities})
    
    crawl_len=crawl_len+1

# %%
news_dict
# Out:
# [{'website': 'CNN',
#   'url': 'https://edition.cnn.com/world/live-news/coronavirus-pandemic-04-28-20-intl/index.html',
#   'headline': 'What you need to know',
#   'entities': []},
#  {'website': 'CNN',
#   'url': 'https://edition.cnn.com/world/live-news/coronavirus-pandemic-04-28-20-intl/index.html',
#   'headline': 'Portugal will end state of emergency this week',
#   'entities': [('Portugal', 'GPE'), ('this week', 'DATE')]},
#  {'website': 'CNN',
#   'url': 'https://edition.cnn.com/world/live-news/coronavirus-pandemic-04-28-20-intl/index.html',
#   'headline': 'Scottish government recommends wearing face coverings in public places',
#   'entities': [('Scottish', 'NORP')]},
#  {'website': 'CNN',
#   'url': 'https://edition.cnn.com/world/live-news/coronavirus-pandemic-04-28-20-intl/index.html',
#   'headline': "125,000 birthday cards sent to war veteran who raised millions for UK's health service",
#   'entities': [('125,000', 'CARDINAL'),
#    ('millions', 'CARDINAL'),
#    ('UK', 'GPE')]},
#  {'website': 'CNN',
#   'url': 'https://edition.cnn.com/world/live-news/coronavirus-pandemic-04-28-20-intl/index.html',
#   'headline': "Just joining us? Here are the key updates you've missed",
#   'entities': []},
#  {'website': 'CNN',
#   'url': 'https://edition.cnn.com/world/live-news/coronavirus-pandemic-04-28-20-intl/index.html',
#   'headline': '"Unfair and irresponsible" to label Chinese products "faulty," says China after India cancels testing kit order',
#   'entities': [('Chinese', 'NORP'), ('China', 'GPE'), ('India', 'GPE')]},
#  {'website': 'CNN',
#   'url': 'https://edition.cnn.com/world/live-news/coronavirus-pandemic-04-28-20-intl/index.html',
#   'headline': 'Lewis Hamilton says he misses Formula 1 racing "every day"',
#   'entities': [('Lewis Hamilton', 'PERSON'), ('Formula 1', 'PRODUCT')]},
#  {'website': 'CNN',
#   'url': 'https://edition.cnn.com/world/live-news/coronavirus-pandemic-04-28-20-intl/index.html',
#   'headline': 'Former New Zealand PM says early ban on Chinese travellers helped curb spread of outbreak',
#   'entities': [('New Zealand', 'GPE'), ('Chinese', 'NORP')]},
#  {'website': 'CNN',
#   'url': 'https://edition.cnn.com/world/live-news/coronavirus-pandemic-04-28-20-intl/index.html',
#   'headline': 'New figures reveal scale of job losses in Spain due to outbreak ',
#   'entities': [('Spain', 'GPE')]},
#  {'website': 'CNN',
#   'url': 'https://edition.cnn.com/world/live-news/coronavirus-pandemic-04-28-20-intl/index.html',
#   'headline': 'Black barbershop owners are divided over coronavirus social distancing',
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Trump lays out new testing 'blueprint' as states weigh reopening",
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Live Blog\xa0/ Latest news on the global pandemic',
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "America's best Instagram quarantine celebrity is a 64-year-old Southern gay man",
#   'entities': [('America', 'GPE'),
#    ('Instagram', 'ORG'),
#    ('Southern', 'NORP')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "America's obsession with Trump lets health officials like Dr. Fauci off the hook",
#   'entities': [('America', 'GPE'), ('Trump', 'GPE'), ('Fauci', 'PERSON')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Those 'COVID-19' weight gain jokes reveal the toxic power of diet culture",
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'In a plagued stretch of Louisiana known as Cancer Alley, coronavirus compounds deaths',
#   'entities': [('Louisiana', 'GPE'), ('Cancer Alley', 'PERSON')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Coronavirus forces America's musicians down a new and delightful path",
#   'entities': [('America', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Prisons overwhelmed, inmates terrified and social dynamics changing behind bars',
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Blue Angels and Thunderbirds to honor coronavirus responders with flyovers',
#   'entities': [('Blue Angels', 'ORG'), ('Thunderbirds', 'ORG')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Face masks for passengers now required on all JetBlue flights',
#   'entities': [('JetBlue', 'ORG')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "'Naked concerns': Doctors strip down to protest lack of protective equipment",
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Pug tests positive for coronavirus, may be first for dog in U.S.',
#   'entities': [('first', 'ORDINAL'), ('U.S.', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Coronavirus reshapes special election for Cummings' Maryland House seat",
#   'entities': [('Cummings', 'ORG'), ('Maryland House', 'ORG')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Troy Sneed, Grammy-nominated gospel singer, dies at 52 from coronavirus complications',
#   'entities': [('Troy Sneed', 'PERSON'), ('52', 'CARDINAL')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Over 30 percent of Americans have witnessed COVID-19 bias against Asians, poll says',
#   'entities': [('Over 30 percent', 'PERCENT'),
#    ('Americans', 'NORP'),
#    ('Asians', 'NORP')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Detroit health care worker dies after being denied coronavirus test 4 times, daughter says',
#   'entities': [('Detroit', 'GPE'), ('4', 'CARDINAL')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'California men accused of peddling millions of nonexistent masks in alleged coronavirus scam',
#   'entities': [('California', 'GPE'), ('millions', 'CARDINAL')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Trump lays out new coronavirus testing 'blueprint' as states weigh reopening",
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Chicago mayor blasts video of 'reckless and utterly unacceptable' house party",
#   'entities': [('Chicago', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "L.A. Lakers qualified for an emergency PPP loan — why didn't nonprofits?",
#   'entities': [('L.A. Lakers', 'ORG'), ('PPP', 'ORG')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Julián Castro: Latinos grapple with 'the worst of all worlds' amid coronavirus pandemic",
#   'entities': [('Julián Castro', 'PERSON')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "'Extremely disappointing' and 'entirely predictable' — slowdowns and lockouts plague second round of PPP",
#   'entities': [('second', 'ORDINAL'), ('PPP', 'ORG')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Have you been mistakenly accused of not social distancing because of apparent stereotyping? Share your experience',
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Inside an 'army' of COVID-19 contact tracers in Massachusetts",
#   'entities': [('Massachusetts', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Pushback on Trump state 'bailout' swipe: Who's really getting rescued?",
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'S. Korea is leading the pack in its coronavirus response. The price? A new way of life.',
#   'entities': [('S. Korea', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Instagram's cofounders left Facebook. Now, they're working on a coronavirus website.",
#   'entities': [('Instagram', 'ORG'), ('Facebook', 'ORG')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Magic Johnson: Sports will first return without fans in the stands',
#   'entities': [('Magic Johnson', 'PERSON'), ('first', 'ORDINAL')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'L.A. Lakers return $4.6M in federal relief aid',
#   'entities': [('L.A. Lakers', 'ORG'), ('$4.6M', 'MONEY')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Trump: Federal govt. shouldn't rescue states and cities struggling under pandemic",
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'As most remain home, some states begin to slowly reopen',
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'In Detroit, grief runs deep as city grapples with COVID-19',
#   'entities': [('Detroit', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Pelosi says Democrats will push for mail-in voting in next relief package',
#   'entities': [('Pelosi', 'ORG'), ('Democrats', 'NORP')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "'Another pandemic': Domestic abuse calls spike in Latin America",
#   'entities': [('Latin America', 'LOC')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Nursing home industry pushes for legal immunity during COVID-19 emergency',
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Tyson Foods chairman warns: 'The food supply chain is breaking'",
#   'entities': [('Tyson Foods', 'ORG')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Doctor prevented from seeing kids after husband said she posed coronavirus threat',
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "As 'quarantine fatigue' sets in, more people venturing out, study finds",
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Automakers adjust to 'new normal' as they prepare to reopen plants",
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "His fight with virus is over, but British PM warns country now is time of 'maximum risk'",
#   'entities': [('British', 'NORP')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Grieving is hard, but new text service means you don't have to do it alone",
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Coronavirus may be strike three for the Burlington Bees',
#   'entities': [('three', 'CARDINAL'), ('the Burlington Bees', 'PRODUCT')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Ballot initiatives struggle to qualify for 2020 election',
#   'entities': [('2020', 'DATE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Louisiana pastor, while on house arrest, again defies coronavirus order with church service',
#   'entities': [('Louisiana', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Governors urge Trump to keep briefings 'fact-based' after disinfectant comments",
#   'entities': [('Trump', 'ORG')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Spanish flu-era diaries give Ohio family hope',
#   'entities': [('Spanish', 'NORP'), ('Ohio', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Small businesses say they need more than 2 months of help to survive coronavirus crisis',
#   'entities': [('more than 2 months', 'DATE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Rolling Stones coronavirus lockdown single 'Living in a Ghost Town' hits No. 1 on iTunes",
#   'entities': [('1', 'CARDINAL'), ('iTunes', 'ORG')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "As Dr. Fauci, Brad Pitt diagnoses Trump on 'SNL'",
#   'entities': [('Fauci', 'PERSON'),
#    ('Brad Pitt', 'PERSON'),
#    ('Trump', 'PERSON'),
#    ('SNL', 'ORG')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "'Outrageous,' 'irresponsible': Governors slam McConnell over bankruptcy comments",
#   'entities': [('slam McConnell', 'PERSON')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Birx: U.S. needs a 'breakthrough' on antigen testing to aid in reopening",
#   'entities': [('Birx', 'GPE'), ('U.S.', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Critics say police target minorities more than white protesters over social distancing',
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Kids miss more than just class with schools closed. How can you help them adjust?',
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "VA has provided few answers around agency's virus study, veteran advocates say",
#   'entities': [('VA', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'The Zoom shiva: Jewish funerals and mourning in the age of COVID',
#   'entities': [('Zoom', 'PERSON'), ('Jewish', 'NORP')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'For students in rural Puerto Rico, remote learning amid coronavirus is a tough challenge',
#   'entities': [('Puerto Rico', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'As restaurants stay closed, chefs still cooking — for health care workers',
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "WHO warns there's no evidence of coronavirus immunity as global death toll reaches 200,000",
#   'entities': [('200,000', 'CARDINAL')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'MSNBC Special Report: Testing and the Road to Reopening',
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Want a mask contract? A White House connection helps',
#   'entities': [('White House', 'ORG')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'At a NY nursing home forced to take COVID-19 patients, 24 residents have died',
#   'entities': [('NY', 'GPE'), ('24', 'CARDINAL')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Affairs, hoarders and hope: Read anonymous confessions in the time of the coronavirus',
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "NBC News special report: 'Coronavirus Pandemic'",
#   'entities': [('NBC News', 'ORG')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Coronavirus: What you need to know',
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "'Into The Red Zone': An NBC News NOW documentary ",
#   'entities': [('NBC News', 'ORG')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Portrait of a neighborhood under lockdown',
#   'entities': [('Portrait', 'PERSON')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Photos capture empty cities across the globe',
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'New Yorkers are giving nightly ovations to health workers. These are their portraits',
#   'entities': [('New Yorkers', 'NORP')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Exonerated man freed from prison, now in hotel quarantine: 'I could watch Netflix!'",
#   'entities': [('Netflix', 'PERSON')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "America needs universal testing. Here's how we'll get there.",
#   'entities': [('America', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Drinking bleach will not cure coronavirus. Here's what it could do instead.",
#   'entities': []},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Touch a shadow, 'You're it!': New routines as Denmark returns to school",
#   'entities': [('Denmark', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Trump's White House briefings may be scaled back",
#   'entities': [('Trump', 'GPE'), ('White House', 'ORG')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'California heat wave draws large crowds to beaches despite stay-at-home order',
#   'entities': [('California', 'GPE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "White House considering scaling back Trump's daily coronavirus briefings in coming weeks",
#   'entities': [('White House', 'ORG'),
#    ("Trump's", 'ORG'),
#    ('daily', 'DATE'),
#    ('coming weeks', 'DATE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'White House considers scaling back daily briefings',
#   'entities': [('White House', 'ORG'), ('daily', 'DATE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Dad, 32, writes heart-wrenching note to wife, kids before dying of coronavirus',
#   'entities': [('32', 'DATE')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': "Fauci's absence from recent coronavirus briefings draws notice",
#   'entities': [('Fauci', 'ORG')]},
#  {'website': 'NBC',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'headline': 'Global coronavirus death toll surpasses 200,000, as world leaders commit to finding vaccine',
#   'entities': [('200,000', 'CARDINAL')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'Latest news for health care. ',
#   'entities': []},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': "On Tuesday, de Blasio announced plans to hire 1,000 health workers to track coronavirus cases as well as anyone who has come into contact with someone who's tested positive for Covid-19.",
#   'entities': [('Tuesday', 'DATE'),
#    ('de Blasio', 'ORG'),
#    ('1,000', 'CARDINAL')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'Health officials in the UK have warned that Covid-19 could be causing a new and rare inflammatory condition in children.',
#   'entities': [('UK', 'GPE')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': "Quest screens patients online to determine whether or not an antibody test is appropriate and then sends them to have their blood drawn at one of Quest's 2,200 laboratories, Quest said.",
#   'entities': [('one', 'CARDINAL'),
#    ('Quest', 'ORG'),
#    ('2,200', 'CARDINAL'),
#    ('Quest', 'ORG')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'Covid-19 has infected more than 3 million people around the world, killing at least 211,522 people.',
#   'entities': [('Covid-19', 'ORG'),
#    ('more than 3 million', 'CARDINAL'),
#    ('at least 211,522', 'CARDINAL')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'Stocks are set to advance as Dow stocks 3M, Caterpillar and Pfizer rise on earnings and U.S. oil prices come off their lows.',
#   'entities': [('Dow', 'ORG'),
#    ('3', 'CARDINAL'),
#    ('Caterpillar', 'ORG'),
#    ('Pfizer', 'PERSON'),
#    ('U.S.', 'GPE')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'As the coronavirus pandemic continues to escalate, doctors around the U.S. are joining lawyers and financial advisors in urging Americans to create the essential documents necessary to help medical providers better coordinate care.',
#   'entities': [('U.S.', 'GPE'), ('Americans', 'NORP')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'It estimates it can potentially produce "millions" of coronavirus vaccine doses by the end of this year and "hundreds of millions of doses" in 2021 if the vaccine is successful.',
#   'entities': [('millions', 'CARDINAL'),
#    ('the end of this year', 'DATE'),
#    ('hundreds of millions', 'CARDINAL'),
#    ('2021', 'DATE')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': "Germany's coronavirus infection rate has edged up, prompting the head of the country's infectious diseases institute to urge people to stay at home as much as possible.",
#   'entities': [('Germany', 'GPE')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'The U.S. is not even "remotely prepared" to re-open, an expert said on Tuesday as some states are set to lift lockdowns that had been imposed to contain the coronavirus outbreak.',
#   'entities': [('U.S.', 'GPE'), ('Tuesday', 'DATE')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'European markets gained on Tuesday as investors monitor the potential easing of coronavirus lockdowns around the world, along with a host of corporate earnings.',
#   'entities': [('European', 'NORP'), ('Tuesday', 'DATE')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': "Germany's coronavirus infection rate has reportedly edged up while Spain's daily death rate has eased.",
#   'entities': [('Germany', 'GPE'), ('Spain', 'GPE'), ('daily', 'DATE')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'American Airlines will require flight attendants wear face masks and will provide passengers with them because of concerns about coronavirus.',
#   'entities': [('American Airlines', 'ORG')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'Boeing is planning to resume production of 787 Dreamliners at its South Carolina factory early next month after a nearly monthlong closure because of the coronavirus.',
#   'entities': [('Boeing', 'ORG'),
#    ('787', 'CARDINAL'),
#    ('South Carolina', 'GPE'),
#    ('early next month', 'DATE')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': '"All those things and many more, changes to our physical facilities, for instance, will be necessary for us to conclude that we are safe," Purdue University President Mitch Daniels told CNBC.',
#   'entities': [('Purdue University', 'ORG'),
#    ('Mitch Daniels', 'PERSON'),
#    ('CNBC', 'ORG')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'The news conference, to be held in the Rose Garden, appears to replace the daily coronavirus task force briefing, which had been scheduled for the same time Monday. Trump has been the subject of criticism for his dangerous speculation about whether injecting disinfectants can help to treat Covid-19.',
#   'entities': [('the Rose Garden', 'FAC'),
#    ('daily', 'DATE'),
#    ('the same time Monday', 'DATE'),
#    ('Trump', 'PERSON')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'More than 1.9 million unemployment claims have been filed in Texas since the outbreak began and the state has paid out more than $2 billion, Abbott said.',
#   'entities': [('More than 1.9 million', 'CARDINAL'),
#    ('Texas', 'GPE'),
#    ('more than $2 billion', 'MONEY'),
#    ('Abbott', 'PERSON')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': "San Francisco Mayor London Breed announced Monday that health officials are extending the city's stay-at-home order through May.",
#   'entities': [('San Francisco', 'GPE'),
#    ('London Breed', 'PERSON'),
#    ('Monday', 'DATE')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': '"Hospitals want to assure patients that if they have an issue, dial 911 and get to the hospital," Medtronic Executive Chairman Omar Ishrak told CNBC.',
#   'entities': [('911', 'CARDINAL'),
#    ('Medtronic Executive', 'ORG'),
#    ('Omar Ishrak', 'PERSON'),
#    ('CNBC', 'ORG')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'Some countries are considering issuing so-called immunity passports to people who have antibodies against Covid-19, enabling them to travel or return to work.',
#   'entities': []},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': '"We believe that the overarching federal plan seems to be very much based on science," Dr. Mike Ryan, executive director of WHO\'s emergencies program, said of the U.S.',
#   'entities': [('Mike Ryan', 'PERSON'), ('WHO', 'ORG'), ('U.S.', 'GPE')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': "Cuomo's remarks come as health experts and political leaders, including those at the White House, warn that the coronavirus is likely to persist through the fall and winter.",
#   'entities': [('Cuomo', 'PERSON'),
#    ('the White House', 'ORG'),
#    ('winter', 'DATE')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'A new CNBC index that tracks companies working on a Covid-19 cure shows how closely the stock market is following drug equities.',
#   'entities': [('CNBC', 'ORG')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'The World Health Organization warned Monday that children across the world will die as the coronavirus pandemic forces some countries to temporarily halt vaccinations for other deadly diseases such as polio.',
#   'entities': [('The World Health Organization', 'ORG'), ('Monday', 'DATE')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'Say hello to the high-walled cubicles made famous in the 1999 film, "Office Space," because they\'re about to make a comeback.',
#   'entities': [('1999', 'DATE'), ('Office Space', 'WORK_OF_ART')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': '"Now how long that immunity lasts, how strong it is, we don\'t know," the former FDA chief told CNBC on Monday.',
#   'entities': [('FDA', 'ORG'), ('CNBC', 'ORG'), ('Monday', 'DATE')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'Earlier last week, Cuomo released the preliminary results of a statewide coronavirus antibody testing study, which indicated that an estimated 13.9% of the New Yorkers have likely had Covid-19 already.',
#   'entities': [('Earlier last week', 'DATE'),
#    ('Cuomo', 'ORG'),
#    ('an estimated 13.9%', 'PERCENT'),
#    ('New Yorkers', 'NORP')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'Boeing is preparing for a yearslong slump in air travel, which will force the manufacturer to shrink to meet weak demand.',
#   'entities': [('Boeing', 'ORG')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'CVS and UPS will start using drones to deliver prescription medications to The Village residents, a Florida retirement community, in order to maintain social distancing measures.',
#   'entities': [('CVS', 'ORG'),
#    ('UPS', 'ORG'),
#    ('Village', 'ORG'),
#    ('Florida', 'GPE')]},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': 'WHO is holding a press briefing on the coronavirus pandemic.',
#   'entities': []},
#  {'website': 'CNBC',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'headline': "Capacity to test broadly throughout the population and to trace contacts with those who test positive for Covid-19 is a crucial element of the state's plans to lift restrictions, New York Gov. Andrew Cuomo have previously said.",
#   'entities': [('New York', 'GPE'), ('Andrew Cuomo', 'PERSON')]}]

# %%
import pandas as pd

# %%
news_df=pd.DataFrame(news_dict)

# %%
pd.set_option('max_colwidth', 800)

news_df.head(20)
# Out:
#    website  \
# 0      CNN
# 1      CNN
# 2      CNN
# 3      CNN
# 4      CNN
# 5      CNN
# 6      CNN
# 7      CNN
# 8      CNN
# 9      CNN
# 10     NBC
# 11     NBC
# 12     NBC
# 13     NBC
# 14     NBC
# 15     NBC
# 16     NBC
# 17     NBC
# 18     NBC
# 19     NBC
#
#                                                                                       url  \
# 0   https://edition.cnn.com/world/live-news/coronavirus-pandemic-04-28-20-intl/index.html
# 1   https://edition.cnn.com/world/live-news/coronavirus-pandemic-04-28-20-intl/index.html
# 2   https://edition.cnn.com/world/live-news/coronavirus-pandemic-04-28-20-intl/index.html
# 3   https://edition.cnn.com/world/live-news/coronavirus-pandemic-04-28-20-intl/index.html
# 4   https://edition.cnn.com/world/live-news/coronavirus-pandemic-04-28-20-intl/index.html
# 5   https://edition.cnn.com/world/live-news/coronavirus-pandemic-04-28-20-intl/index.html
# 6   https://edition.cnn.com/world/live-news/coronavirus-pandemic-04-28-20-intl/index.html
# 7   https://edition.cnn.com/world/live-news/coronavirus-pandemic-04-28-20-intl/index.html
# 8   https://edition.cnn.com/world/live-news/coronavirus-pandemic-04-28-20-intl/index.html
# 9   https://edition.cnn.com/world/live-news/coronavirus-pandemic-04-28-20-intl/index.html
# 10                                             https://www.nbcnews.com/health/coronavirus
# 11                                             https://www.nbcnews.com/health/coronavirus
# 12                                             https://www.nbcnews.com/health/coronavirus
# 13                                             https://www.nbcnews.com/health/coronavirus
# 14                                             https://www.nbcnews.com/health/coronavirus
# 15                                             https://www.nbcnews.com/health/coronavirus
# 16                                             https://www.nbcnews.com/health/coronavirus
# 17                                             https://www.nbcnews.com/health/coronavirus
# 18                                             https://www.nbcnews.com/health/coronavirus
# 19                                             https://www.nbcnews.com/health/coronavirus
#
#                                                                                                            headline  \
# 0                                                                                             What you need to know
# 1                                                                    Portugal will end state of emergency this week
# 2                                            Scottish government recommends wearing face coverings in public places
# 3                            125,000 birthday cards sent to war veteran who raised millions for UK's health service
# 4                                                           Just joining us? Here are the key updates you've missed
# 5   "Unfair and irresponsible" to label Chinese products "faulty," says China after India cancels testing kit order
# 6                                                        Lewis Hamilton says he misses Formula 1 racing "every day"
# 7                         Former New Zealand PM says early ban on Chinese travellers helped curb spread of outbreak
# 8                                                  New figures reveal scale of job losses in Spain due to outbreak
# 9                                            Black barbershop owners are divided over coronavirus social distancing
# 10                                                 Trump lays out new testing 'blueprint' as states weigh reopening
# 11                                                                   Live Blog / Latest news on the global pandemic
# 12                                  America's best Instagram quarantine celebrity is a 64-year-old Southern gay man
# 13                                 America's obsession with Trump lets health officials like Dr. Fauci off the hook
# 14                                        Those 'COVID-19' weight gain jokes reveal the toxic power of diet culture
# 15                            In a plagued stretch of Louisiana known as Cancer Alley, coronavirus compounds deaths
# 16                                            Coronavirus forces America's musicians down a new and delightful path
# 17                                  Prisons overwhelmed, inmates terrified and social dynamics changing behind bars
# 18                                       Blue Angels and Thunderbirds to honor coronavirus responders with flyovers
# 19                                                    Face masks for passengers now required on all JetBlue flights
#
#                                                   entities
# 0                                                       []
# 1                     [(Portugal, GPE), (this week, DATE)]
# 2                                       [(Scottish, NORP)]
# 3   [(125,000, CARDINAL), (millions, CARDINAL), (UK, GPE)]
# 4                                                       []
# 5            [(Chinese, NORP), (China, GPE), (India, GPE)]
# 6         [(Lewis Hamilton, PERSON), (Formula 1, PRODUCT)]
# 7                    [(New Zealand, GPE), (Chinese, NORP)]
# 8                                           [(Spain, GPE)]
# 9                                                       []
# 10                                                      []
# 11                                                      []
# 12    [(America, GPE), (Instagram, ORG), (Southern, NORP)]
# 13         [(America, GPE), (Trump, GPE), (Fauci, PERSON)]
# 14                                                      []
# 15              [(Louisiana, GPE), (Cancer Alley, PERSON)]
# 16                                        [(America, GPE)]
# 17                                                      []
# 18               [(Blue Angels, ORG), (Thunderbirds, ORG)]
# 19                                        [(JetBlue, ORG)]

# %%
news_final_df=pd.concat([news_df[['website','url','headline']],news_df['entities'].apply(pd.Series)],axis=1)

# %%
news_final_df.head()
# Out:
#   website  \
# 0     CNN
# 1     CNN
# 2     CNN
# 3     CNN
# 4     CNN
#
#                                                                                      url  \
# 0  https://edition.cnn.com/world/live-news/coronavirus-pandemic-04-28-20-intl/index.html
# 1  https://edition.cnn.com/world/live-news/coronavirus-pandemic-04-28-20-intl/index.html
# 2  https://edition.cnn.com/world/live-news/coronavirus-pandemic-04-28-20-intl/index.html
# 3  https://edition.cnn.com/world/live-news/coronavirus-pandemic-04-28-20-intl/index.html
# 4  https://edition.cnn.com/world/live-news/coronavirus-pandemic-04-28-20-intl/index.html
#
#                                                                                  headline  \
# 0                                                                   What you need to know
# 1                                          Portugal will end state of emergency this week
# 2                  Scottish government recommends wearing face coverings in public places
# 3  125,000 birthday cards sent to war veteran who raised millions for UK's health service
# 4                                 Just joining us? Here are the key updates you've missed
#
#                      0                     1          2    3    4
# 0                  NaN                   NaN        NaN  NaN  NaN
# 1      (Portugal, GPE)     (this week, DATE)        NaN  NaN  NaN
# 2     (Scottish, NORP)                   NaN        NaN  NaN  NaN
# 3  (125,000, CARDINAL)  (millions, CARDINAL)  (UK, GPE)  NaN  NaN
# 4                  NaN                   NaN        NaN  NaN  NaN

# %%
news_df.to_csv("C:/Users/hp/Desktop/dataset/news_crawling.csv")
